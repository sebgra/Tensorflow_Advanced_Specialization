# %% [markdown]
# # Ungraded Lab: Build a Multi-output Model
#
# In this lab, we'll show how you can build models with more than one output. The dataset we will be working on is available from the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Energy+efficiency). It is an Energy Efficiency dataset which uses the bulding features (e.g. wall area, roof area) as inputs and has two outputs: Cooling Load and Heating Load. Let's see how we can build a model to train on this data.

# %% [markdown]
# ## Imports

# %%
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Utilities
#
# We define a few utilities for data conversion and visualization to make our code more neat.

# %%
def format_output(data):
    y1 = data.pop('Y1')
    y1 = np.array(y1)
    y2 = data.pop('Y2')
    y2 = np.array(y2)
    return y1, y2


def norm(x):
    return (x - train_stats['mean']) / train_stats['std']


def plot_diff(y_true, y_pred, title=''):
    plt.scatter(y_true, y_pred)
    plt.title(title)
    plt.xlabel('True Values')
    plt.ylabel('Predictions')
    plt.axis('equal')
    plt.axis('square')
    plt.xlim(plt.xlim())
    plt.ylim(plt.ylim())
    plt.plot([-100, 100], [-100, 100])
    plt.show()


def plot_metrics(metric_name, title, ylim=5):
    plt.title(title)
    plt.ylim(0, ylim)
    plt.plot(history.history[metric_name], color='blue', label=metric_name)
    plt.plot(history.history['val_' + metric_name], color='green', label='val_' + metric_name)
    plt.show()

# %% [markdown]
# ## Prepare the Data
#
# We download the dataset and format it for training.

# %%
# Specify data URI
URI = './data/ENB2012_data.xlsx'

# Use pandas excel reader
df = pd.read_excel(URI)
df = df.sample(frac=1).reset_index(drop=True)

# Split the data into train and test with 80 train / 20 test
train, test = train_test_split(df, test_size=0.2)
train_stats = train.describe()

# Get Y1 and Y2 as the 2 outputs and format them as np arrays
train_stats.pop('Y1')
train_stats.pop('Y2')
train_stats = train_stats.transpose()
train_Y = format_output(train)
test_Y = format_output(test)

# Normalize the training and test data
norm_train_X = norm(train)
norm_test_X = norm(test)

# %% [markdown]
# ## Build the Model
#
# Here is how we'll build the model using the functional syntax. Notice that we can specify a list of outputs (i.e. `[y1_output, y2_output]`) when we instantiate the `Model()` class.

# %%
# Define model layers.
input_layer = Input(shape=(len(train .columns),))
first_dense = Dense(units='128', activation='relu')(input_layer)
second_dense = Dense(units='128', activation='relu')(first_dense)

# Y1 output will be fed directly from the second dense
y1_output = Dense(units='1', name='y1_output')(second_dense)
third_dense = Dense(units='64', activation='relu')(second_dense)

# Y2 output will come via the third dense
y2_output = Dense(units='1', name='y2_output')(third_dense)

# Define the model with the input layer and a list of output layers
model = Model(inputs=input_layer, outputs=[y1_output, y2_output])

print(model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 8)]          0
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128)          1152        input_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 128)          16512       dense[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 64)           8256        dense_1[0][0]
# __________________________________________________________________________________________________
# y1_output (Dense)               (None, 1)            129         dense_1[0][0]
# __________________________________________________________________________________________________
# y2_output (Dense)               (None, 1)            65          dense_2[0][0]
# ==================================================================================================
# Total params: 26,114
# Trainable params: 26,114
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %% [markdown]
# ## Configure parameters
#
# We specify the optimizer as well as the loss and metrics for each output.

# %%
# Specify the optimizer, and compile the model with loss functions for both outputs
optimizer = tf.keras.optimizers.SGD(lr=0.001)
model.compile(optimizer=optimizer,
              loss={'y1_output': 'mse', 'y2_output': 'mse'},
              metrics={'y1_output': tf.keras.metrics.RootMeanSquaredError(),
                       'y2_output': tf.keras.metrics.RootMeanSquaredError()})

# %% [markdown]
# ## Train the Model

# %%
# Train the model for 500 epochs
history = model.fit(norm_train_X, train_Y,
                    epochs=500, batch_size=10, validation_data=(norm_test_X, test_Y))
# Out:
# Train on 614 samples, validate on 154 samples
# Epoch 1/500
# 614/614 [==============================] - 1s 1ms/sample - loss: 267.9498 - y1_output_loss: 127.6167 - y2_output_loss: 138.1352 - y1_output_root_mean_squared_error: 11.3470 - y2_output_root_mean_squared_error: 11.7981 - val_loss: 60.0782 - val_y1_output_loss: 21.8358 - val_y2_output_loss: 36.4137 - val_y1_output_root_mean_squared_error: 4.7345 - val_y2_output_root_mean_squared_error: 6.1370
# Epoch 2/500
# 614/614 [==============================] - 0s 163us/sample - loss: 31.9528 - y1_output_loss: 12.2093 - y2_output_loss: 19.5370 - y1_output_root_mean_squared_error: 3.5041 - y2_output_root_mean_squared_error: 4.4355 - val_loss: 27.0686 - val_y1_output_loss: 11.9658 - val_y2_output_loss: 14.5600 - val_y1_output_root_mean_squared_error: 3.4876 - val_y2_output_root_mean_squared_error: 3.8607
# Epoch 3/500
# 614/614 [==============================] - 0s 170us/sample - loss: 30.1787 - y1_output_loss: 10.7365 - y2_output_loss: 19.2857 - y1_output_root_mean_squared_error: 3.2896 - y2_output_root_mean_squared_error: 4.3997 - val_loss: 32.6840 - val_y1_output_loss: 14.8051 - val_y2_output_loss: 17.2632 - val_y1_output_root_mean_squared_error: 3.8639 - val_y2_output_root_mean_squared_error: 4.2136
# Epoch 4/500
# 614/614 [==============================] - 0s 164us/sample - loss: 24.0757 - y1_output_loss: 9.4956 - y2_output_loss: 14.3912 - y1_output_root_mean_squared_error: 3.0931 - y2_output_root_mean_squared_error: 3.8090 - val_loss: 27.2518 - val_y1_output_loss: 9.7316 - val_y2_output_loss: 16.6631 - val_y1_output_root_mean_squared_error: 3.1577 - val_y2_output_root_mean_squared_error: 4.1570
# Epoch 5/500
# 614/614 [==============================] - 0s 156us/sample - loss: 22.7885 - y1_output_loss: 8.6626 - y2_output_loss: 14.2562 - y1_output_root_mean_squared_error: 2.9222 - y2_output_root_mean_squared_error: 3.7748 - val_loss: 47.1809 - val_y1_output_loss: 18.8099 - val_y2_output_loss: 26.9944 - val_y1_output_root_mean_squared_error: 4.3938 - val_y2_output_root_mean_squared_error: 5.2797
# Epoch 6/500
# 614/614 [==============================] - 0s 157us/sample - loss: 21.7946 - y1_output_loss: 8.9036 - y2_output_loss: 13.1348 - y1_output_root_mean_squared_error: 2.9544 - y2_output_root_mean_squared_error: 3.6147 - val_loss: 51.0228 - val_y1_output_loss: 14.4794 - val_y2_output_loss: 35.1654 - val_y1_output_root_mean_squared_error: 3.8606 - val_y2_output_root_mean_squared_error: 6.0099
# Epoch 7/500
# 614/614 [==============================] - 0s 150us/sample - loss: 22.3902 - y1_output_loss: 8.4240 - y2_output_loss: 13.8309 - y1_output_root_mean_squared_error: 2.9132 - y2_output_root_mean_squared_error: 3.7287 - val_loss: 19.4701 - val_y1_output_loss: 8.1447 - val_y2_output_loss: 11.4604 - val_y1_output_root_mean_squared_error: 2.8729 - val_y2_output_root_mean_squared_error: 3.3491
# Epoch 8/500
# 614/614 [==============================] - 0s 151us/sample - loss: 22.3705 - y1_output_loss: 8.5184 - y2_output_loss: 13.8037 - y1_output_root_mean_squared_error: 2.9292 - y2_output_root_mean_squared_error: 3.7135 - val_loss: 29.3737 - val_y1_output_loss: 11.1838 - val_y2_output_loss: 17.4714 - val_y1_output_root_mean_squared_error: 3.3783 - val_y2_output_root_mean_squared_error: 4.2380
# Epoch 9/500
# 614/614 [==============================] - 0s 149us/sample - loss: 20.4716 - y1_output_loss: 8.0058 - y2_output_loss: 12.5644 - y1_output_root_mean_squared_error: 2.8232 - y2_output_root_mean_squared_error: 3.5357 - val_loss: 45.1635 - val_y1_output_loss: 14.9097 - val_y2_output_loss: 29.4253 - val_y1_output_root_mean_squared_error: 3.8888 - val_y2_output_root_mean_squared_error: 5.4809
# Epoch 10/500
# 614/614 [==============================] - 0s 149us/sample - loss: 23.0931 - y1_output_loss: 8.4239 - y2_output_loss: 14.6420 - y1_output_root_mean_squared_error: 2.8976 - y2_output_root_mean_squared_error: 3.8337 - val_loss: 21.9984 - val_y1_output_loss: 7.8670 - val_y2_output_loss: 13.7243 - val_y1_output_root_mean_squared_error: 2.8134 - val_y2_output_root_mean_squared_error: 3.7528
# Epoch 11/500
# 614/614 [==============================] - 0s 148us/sample - loss: 17.3655 - y1_output_loss: 7.1195 - y2_output_loss: 10.1456 - y1_output_root_mean_squared_error: 2.6779 - y2_output_root_mean_squared_error: 3.1929 - val_loss: 17.2643 - val_y1_output_loss: 7.7396 - val_y2_output_loss: 9.5783 - val_y1_output_root_mean_squared_error: 2.7741 - val_y2_output_root_mean_squared_error: 3.0933
# Epoch 12/500
# 614/614 [==============================] - 0s 146us/sample - loss: 19.2884 - y1_output_loss: 7.6275 - y2_output_loss: 11.4916 - y1_output_root_mean_squared_error: 2.7728 - y2_output_root_mean_squared_error: 3.4059 - val_loss: 24.5116 - val_y1_output_loss: 9.7116 - val_y2_output_loss: 14.1777 - val_y1_output_root_mean_squared_error: 3.1551 - val_y2_output_root_mean_squared_error: 3.8153
# Epoch 13/500
# 614/614 [==============================] - 0s 146us/sample - loss: 20.7890 - y1_output_loss: 7.6396 - y2_output_loss: 13.4005 - y1_output_root_mean_squared_error: 2.7622 - y2_output_root_mean_squared_error: 3.6275 - val_loss: 32.7372 - val_y1_output_loss: 8.7400 - val_y2_output_loss: 25.7731 - val_y1_output_root_mean_squared_error: 2.9000 - val_y2_output_root_mean_squared_error: 4.9322
# Epoch 14/500
# 614/614 [==============================] - 0s 147us/sample - loss: 16.1077 - y1_output_loss: 6.6366 - y2_output_loss: 9.4662 - y1_output_root_mean_squared_error: 2.5711 - y2_output_root_mean_squared_error: 3.0817 - val_loss: 30.5779 - val_y1_output_loss: 9.2769 - val_y2_output_loss: 20.4780 - val_y1_output_root_mean_squared_error: 3.0803 - val_y2_output_root_mean_squared_error: 4.5924
# Epoch 15/500
# 614/614 [==============================] - 0s 156us/sample - loss: 20.8142 - y1_output_loss: 7.4922 - y2_output_loss: 13.1675 - y1_output_root_mean_squared_error: 2.7468 - y2_output_root_mean_squared_error: 3.6427 - val_loss: 14.5591 - val_y1_output_loss: 6.2382 - val_y2_output_loss: 8.3078 - val_y1_output_root_mean_squared_error: 2.5081 - val_y2_output_root_mean_squared_error: 2.8755
# Epoch 16/500
# 614/614 [==============================] - 0s 152us/sample - loss: 17.2965 - y1_output_loss: 6.6442 - y2_output_loss: 10.5836 - y1_output_root_mean_squared_error: 2.5890 - y2_output_root_mean_squared_error: 3.2548 - val_loss: 17.1646 - val_y1_output_loss: 7.4169 - val_y2_output_loss: 9.9420 - val_y1_output_root_mean_squared_error: 2.7342 - val_y2_output_root_mean_squared_error: 3.1126
# Epoch 17/500
# 614/614 [==============================] - 0s 146us/sample - loss: 20.4643 - y1_output_loss: 7.4173 - y2_output_loss: 13.0674 - y1_output_root_mean_squared_error: 2.7278 - y2_output_root_mean_squared_error: 3.6088 - val_loss: 31.1809 - val_y1_output_loss: 7.5051 - val_y2_output_loss: 25.2601 - val_y1_output_root_mean_squared_error: 2.6905 - val_y2_output_root_mean_squared_error: 4.8931
# Epoch 18/500
# 614/614 [==============================] - 0s 148us/sample - loss: 18.0095 - y1_output_loss: 6.5582 - y2_output_loss: 11.4140 - y1_output_root_mean_squared_error: 2.5662 - y2_output_root_mean_squared_error: 3.3800 - val_loss: 46.4875 - val_y1_output_loss: 8.8000 - val_y2_output_loss: 39.8911 - val_y1_output_root_mean_squared_error: 2.9075 - val_y2_output_root_mean_squared_error: 6.1671
# Epoch 19/500
# 614/614 [==============================] - 0s 167us/sample - loss: 16.1761 - y1_output_loss: 6.0666 - y2_output_loss: 9.9895 - y1_output_root_mean_squared_error: 2.4738 - y2_output_root_mean_squared_error: 3.1712 - val_loss: 20.7160 - val_y1_output_loss: 6.5093 - val_y2_output_loss: 15.0523 - val_y1_output_root_mean_squared_error: 2.5228 - val_y2_output_root_mean_squared_error: 3.7883
# Epoch 20/500
# 614/614 [==============================] - 0s 152us/sample - loss: 14.6535 - y1_output_loss: 5.6744 - y2_output_loss: 8.9136 - y1_output_root_mean_squared_error: 2.3809 - y2_output_root_mean_squared_error: 2.9975 - val_loss: 11.9153 - val_y1_output_loss: 5.0085 - val_y2_output_loss: 7.1207 - val_y1_output_root_mean_squared_error: 2.2229 - val_y2_output_root_mean_squared_error: 2.6409
# Epoch 21/500
# 614/614 [==============================] - 0s 149us/sample - loss: 12.2829 - y1_output_loss: 5.0660 - y2_output_loss: 7.2630 - y1_output_root_mean_squared_error: 2.2421 - y2_output_root_mean_squared_error: 2.6937 - val_loss: 14.9801 - val_y1_output_loss: 5.8679 - val_y2_output_loss: 8.8303 - val_y1_output_root_mean_squared_error: 2.4418 - val_y2_output_root_mean_squared_error: 3.0030
# Epoch 22/500
# 614/614 [==============================] - 0s 150us/sample - loss: 14.3152 - y1_output_loss: 5.6341 - y2_output_loss: 8.5489 - y1_output_root_mean_squared_error: 2.3847 - y2_output_root_mean_squared_error: 2.9374 - val_loss: 16.9761 - val_y1_output_loss: 7.1143 - val_y2_output_loss: 9.4797 - val_y1_output_root_mean_squared_error: 2.7032 - val_y2_output_root_mean_squared_error: 3.1095
# Epoch 23/500
# 614/614 [==============================] - 0s 149us/sample - loss: 12.4848 - y1_output_loss: 5.0466 - y2_output_loss: 7.4491 - y1_output_root_mean_squared_error: 2.2366 - y2_output_root_mean_squared_error: 2.7354 - val_loss: 16.0672 - val_y1_output_loss: 5.3070 - val_y2_output_loss: 10.5078 - val_y1_output_root_mean_squared_error: 2.3188 - val_y2_output_root_mean_squared_error: 3.2696
# Epoch 24/500
# 614/614 [==============================] - 0s 149us/sample - loss: 12.7530 - y1_output_loss: 4.7670 - y2_output_loss: 7.8787 - y1_output_root_mean_squared_error: 2.1931 - y2_output_root_mean_squared_error: 2.8184 - val_loss: 11.7430 - val_y1_output_loss: 4.8363 - val_y2_output_loss: 7.0783 - val_y1_output_root_mean_squared_error: 2.1872 - val_y2_output_root_mean_squared_error: 2.6380
# Epoch 25/500
# 614/614 [==============================] - 0s 146us/sample - loss: 11.4850 - y1_output_loss: 4.7364 - y2_output_loss: 6.7568 - y1_output_root_mean_squared_error: 2.1779 - y2_output_root_mean_squared_error: 2.5964 - val_loss: 22.5930 - val_y1_output_loss: 9.4236 - val_y2_output_loss: 12.5595 - val_y1_output_root_mean_squared_error: 3.1064 - val_y2_output_root_mean_squared_error: 3.5977
# Epoch 26/500
# 614/614 [==============================] - 0s 147us/sample - loss: 11.5513 - y1_output_loss: 4.5511 - y2_output_loss: 6.9589 - y1_output_root_mean_squared_error: 2.1385 - y2_output_root_mean_squared_error: 2.6417 - val_loss: 13.9017 - val_y1_output_loss: 4.4103 - val_y2_output_loss: 10.1642 - val_y1_output_root_mean_squared_error: 2.0708 - val_y2_output_root_mean_squared_error: 3.1006
# Epoch 27/500
# 614/614 [==============================] - 0s 151us/sample - loss: 12.2089 - y1_output_loss: 4.2200 - y2_output_loss: 7.9409 - y1_output_root_mean_squared_error: 2.0624 - y2_output_root_mean_squared_error: 2.8206 - val_loss: 11.8677 - val_y1_output_loss: 3.6999 - val_y2_output_loss: 8.5171 - val_y1_output_root_mean_squared_error: 1.9169 - val_y2_output_root_mean_squared_error: 2.8624
# Epoch 28/500
# 614/614 [==============================] - 0s 146us/sample - loss: 13.5431 - y1_output_loss: 4.9508 - y2_output_loss: 8.7455 - y1_output_root_mean_squared_error: 2.2133 - y2_output_root_mean_squared_error: 2.9401 - val_loss: 17.3555 - val_y1_output_loss: 6.1039 - val_y2_output_loss: 11.8699 - val_y1_output_root_mean_squared_error: 2.4381 - val_y2_output_root_mean_squared_error: 3.3780
# Epoch 29/500
# 614/614 [==============================] - 0s 143us/sample - loss: 11.6461 - y1_output_loss: 3.9957 - y2_output_loss: 7.5740 - y1_output_root_mean_squared_error: 2.0061 - y2_output_root_mean_squared_error: 2.7607 - val_loss: 9.5102 - val_y1_output_loss: 3.3136 - val_y2_output_loss: 6.2492 - val_y1_output_root_mean_squared_error: 1.8181 - val_y2_output_root_mean_squared_error: 2.4909
# Epoch 30/500
# 614/614 [==============================] - 0s 147us/sample - loss: 10.2736 - y1_output_loss: 3.8027 - y2_output_loss: 6.4082 - y1_output_root_mean_squared_error: 1.9543 - y2_output_root_mean_squared_error: 2.5405 - val_loss: 9.7467 - val_y1_output_loss: 3.4320 - val_y2_output_loss: 6.1563 - val_y1_output_root_mean_squared_error: 1.8748 - val_y2_output_root_mean_squared_error: 2.4964
# Epoch 31/500
# 614/614 [==============================] - 0s 148us/sample - loss: 8.7315 - y1_output_loss: 3.3630 - y2_output_loss: 5.3835 - y1_output_root_mean_squared_error: 1.8379 - y2_output_root_mean_squared_error: 2.3138 - val_loss: 8.6250 - val_y1_output_loss: 3.2697 - val_y2_output_loss: 5.2602 - val_y1_output_root_mean_squared_error: 1.8365 - val_y2_output_root_mean_squared_error: 2.2918
# Epoch 32/500
# 614/614 [==============================] - 0s 145us/sample - loss: 8.9873 - y1_output_loss: 3.3419 - y2_output_loss: 5.6422 - y1_output_root_mean_squared_error: 1.8213 - y2_output_root_mean_squared_error: 2.3812 - val_loss: 12.5995 - val_y1_output_loss: 4.1267 - val_y2_output_loss: 8.3055 - val_y1_output_root_mean_squared_error: 2.0447 - val_y2_output_root_mean_squared_error: 2.9015
# Epoch 33/500
# 614/614 [==============================] - 0s 147us/sample - loss: 9.9544 - y1_output_loss: 3.5529 - y2_output_loss: 6.4414 - y1_output_root_mean_squared_error: 1.8824 - y2_output_root_mean_squared_error: 2.5320 - val_loss: 21.5667 - val_y1_output_loss: 6.5070 - val_y2_output_loss: 14.9115 - val_y1_output_root_mean_squared_error: 2.5583 - val_y2_output_root_mean_squared_error: 3.8758
# Epoch 34/500
# 614/614 [==============================] - 0s 148us/sample - loss: 11.4725 - y1_output_loss: 3.6866 - y2_output_loss: 7.7479 - y1_output_root_mean_squared_error: 1.9220 - y2_output_root_mean_squared_error: 2.7890 - val_loss: 13.3151 - val_y1_output_loss: 4.0849 - val_y2_output_loss: 8.8770 - val_y1_output_root_mean_squared_error: 2.0346 - val_y2_output_root_mean_squared_error: 3.0291
# Epoch 35/500
# 614/614 [==============================] - 0s 149us/sample - loss: 7.4661 - y1_output_loss: 2.9079 - y2_output_loss: 4.6427 - y1_output_root_mean_squared_error: 1.6797 - y2_output_root_mean_squared_error: 2.1551 - val_loss: 22.3303 - val_y1_output_loss: 10.1646 - val_y2_output_loss: 11.8931 - val_y1_output_root_mean_squared_error: 3.2048 - val_y2_output_root_mean_squared_error: 3.4727
# Epoch 36/500
# 614/614 [==============================] - 0s 151us/sample - loss: 7.8572 - y1_output_loss: 2.8611 - y2_output_loss: 5.1430 - y1_output_root_mean_squared_error: 1.6923 - y2_output_root_mean_squared_error: 2.2345 - val_loss: 25.5692 - val_y1_output_loss: 5.2148 - val_y2_output_loss: 21.6865 - val_y1_output_root_mean_squared_error: 2.2109 - val_y2_output_root_mean_squared_error: 4.5476
# Epoch 37/500
# 614/614 [==============================] - 0s 150us/sample - loss: 8.3366 - y1_output_loss: 2.8787 - y2_output_loss: 5.4484 - y1_output_root_mean_squared_error: 1.6991 - y2_output_root_mean_squared_error: 2.3345 - val_loss: 20.2169 - val_y1_output_loss: 5.8587 - val_y2_output_loss: 14.9447 - val_y1_output_root_mean_squared_error: 2.3878 - val_y2_output_root_mean_squared_error: 3.8099
# Epoch 38/500
# 614/614 [==============================] - 0s 149us/sample - loss: 10.5907 - y1_output_loss: 3.5172 - y2_output_loss: 7.2604 - y1_output_root_mean_squared_error: 1.8632 - y2_output_root_mean_squared_error: 2.6682 - val_loss: 19.1338 - val_y1_output_loss: 4.0615 - val_y2_output_loss: 15.4433 - val_y1_output_root_mean_squared_error: 2.0102 - val_y2_output_root_mean_squared_error: 3.8850
# Epoch 39/500
# 614/614 [==============================] - 0s 148us/sample - loss: 7.2226 - y1_output_loss: 2.6247 - y2_output_loss: 4.5871 - y1_output_root_mean_squared_error: 1.6241 - y2_output_root_mean_squared_error: 2.1412 - val_loss: 9.2801 - val_y1_output_loss: 2.0707 - val_y2_output_loss: 7.3913 - val_y1_output_root_mean_squared_error: 1.4447 - val_y2_output_root_mean_squared_error: 2.6820
# Epoch 40/500
# 614/614 [==============================] - 0s 144us/sample - loss: 8.7909 - y1_output_loss: 2.9521 - y2_output_loss: 5.8145 - y1_output_root_mean_squared_error: 1.7187 - y2_output_root_mean_squared_error: 2.4160 - val_loss: 12.6702 - val_y1_output_loss: 4.2607 - val_y2_output_loss: 8.1798 - val_y1_output_root_mean_squared_error: 2.0801 - val_y2_output_root_mean_squared_error: 2.8885
# Epoch 41/500
# 614/614 [==============================] - 0s 154us/sample - loss: 8.4985 - y1_output_loss: 2.9259 - y2_output_loss: 5.5015 - y1_output_root_mean_squared_error: 1.7175 - y2_output_root_mean_squared_error: 2.3556 - val_loss: 10.0396 - val_y1_output_loss: 2.1805 - val_y2_output_loss: 8.1125 - val_y1_output_root_mean_squared_error: 1.4759 - val_y2_output_root_mean_squared_error: 2.8038
# Epoch 42/500
# 614/614 [==============================] - 0s 152us/sample - loss: 9.1728 - y1_output_loss: 2.9237 - y2_output_loss: 6.2145 - y1_output_root_mean_squared_error: 1.7162 - y2_output_root_mean_squared_error: 2.4955 - val_loss: 8.5013 - val_y1_output_loss: 2.6400 - val_y2_output_loss: 5.9176 - val_y1_output_root_mean_squared_error: 1.6311 - val_y2_output_root_mean_squared_error: 2.4167
# Epoch 43/500
# 614/614 [==============================] - 0s 152us/sample - loss: 6.6676 - y1_output_loss: 2.1981 - y2_output_loss: 4.4666 - y1_output_root_mean_squared_error: 1.4835 - y2_output_root_mean_squared_error: 2.1135 - val_loss: 7.8149 - val_y1_output_loss: 1.8200 - val_y2_output_loss: 5.9992 - val_y1_output_root_mean_squared_error: 1.3668 - val_y2_output_root_mean_squared_error: 2.4386
# Epoch 44/500
# 614/614 [==============================] - 0s 150us/sample - loss: 7.9208 - y1_output_loss: 2.5962 - y2_output_loss: 5.3269 - y1_output_root_mean_squared_error: 1.6095 - y2_output_root_mean_squared_error: 2.3087 - val_loss: 9.9350 - val_y1_output_loss: 4.0527 - val_y2_output_loss: 5.6686 - val_y1_output_root_mean_squared_error: 2.0247 - val_y2_output_root_mean_squared_error: 2.4157
# Epoch 45/500
# 614/614 [==============================] - 0s 150us/sample - loss: 7.0305 - y1_output_loss: 2.3712 - y2_output_loss: 4.7420 - y1_output_root_mean_squared_error: 1.5378 - y2_output_root_mean_squared_error: 2.1600 - val_loss: 8.7635 - val_y1_output_loss: 2.5549 - val_y2_output_loss: 6.2439 - val_y1_output_root_mean_squared_error: 1.6154 - val_y2_output_root_mean_squared_error: 2.4807
# Epoch 46/500
# 614/614 [==============================] - 0s 149us/sample - loss: 6.2897 - y1_output_loss: 2.1200 - y2_output_loss: 4.1454 - y1_output_root_mean_squared_error: 1.4592 - y2_output_root_mean_squared_error: 2.0397 - val_loss: 9.2365 - val_y1_output_loss: 1.6334 - val_y2_output_loss: 7.7246 - val_y1_output_root_mean_squared_error: 1.2820 - val_y2_output_root_mean_squared_error: 2.7555
# Epoch 47/500
# 614/614 [==============================] - 0s 148us/sample - loss: 6.3221 - y1_output_loss: 2.1200 - y2_output_loss: 4.2022 - y1_output_root_mean_squared_error: 1.4510 - y2_output_root_mean_squared_error: 2.0534 - val_loss: 8.7797 - val_y1_output_loss: 2.5067 - val_y2_output_loss: 6.1718 - val_y1_output_root_mean_squared_error: 1.5874 - val_y2_output_root_mean_squared_error: 2.5020
# Epoch 48/500
# 614/614 [==============================] - 0s 150us/sample - loss: 5.7860 - y1_output_loss: 1.9864 - y2_output_loss: 3.7776 - y1_output_root_mean_squared_error: 1.4160 - y2_output_root_mean_squared_error: 1.9445 - val_loss: 6.2966 - val_y1_output_loss: 1.9743 - val_y2_output_loss: 4.3116 - val_y1_output_root_mean_squared_error: 1.4041 - val_y2_output_root_mean_squared_error: 2.0797
# Epoch 49/500
# 614/614 [==============================] - 0s 147us/sample - loss: 6.5635 - y1_output_loss: 2.1438 - y2_output_loss: 4.4290 - y1_output_root_mean_squared_error: 1.4650 - y2_output_root_mean_squared_error: 2.1017 - val_loss: 17.2510 - val_y1_output_loss: 4.6565 - val_y2_output_loss: 12.4454 - val_y1_output_root_mean_squared_error: 2.1624 - val_y2_output_root_mean_squared_error: 3.5461
# Epoch 50/500
# 614/614 [==============================] - 0s 144us/sample - loss: 6.0484 - y1_output_loss: 1.8333 - y2_output_loss: 4.2589 - y1_output_root_mean_squared_error: 1.3465 - y2_output_root_mean_squared_error: 2.0580 - val_loss: 6.9651 - val_y1_output_loss: 1.6459 - val_y2_output_loss: 5.2886 - val_y1_output_root_mean_squared_error: 1.2898 - val_y2_output_root_mean_squared_error: 2.3025
# Epoch 51/500
# 614/614 [==============================] - 0s 144us/sample - loss: 5.6979 - y1_output_loss: 1.8762 - y2_output_loss: 3.8638 - y1_output_root_mean_squared_error: 1.3745 - y2_output_root_mean_squared_error: 1.9516 - val_loss: 6.3600 - val_y1_output_loss: 1.9294 - val_y2_output_loss: 4.3835 - val_y1_output_root_mean_squared_error: 1.3924 - val_y2_output_root_mean_squared_error: 2.1027
# Epoch 52/500
# 614/614 [==============================] - 0s 145us/sample - loss: 6.0723 - y1_output_loss: 1.9062 - y2_output_loss: 4.1194 - y1_output_root_mean_squared_error: 1.3838 - y2_output_root_mean_squared_error: 2.0390 - val_loss: 8.2424 - val_y1_output_loss: 3.1519 - val_y2_output_loss: 4.8544 - val_y1_output_root_mean_squared_error: 1.7972 - val_y2_output_root_mean_squared_error: 2.2389
# Epoch 53/500
# 614/614 [==============================] - 0s 142us/sample - loss: 5.7019 - y1_output_loss: 1.8445 - y2_output_loss: 3.8414 - y1_output_root_mean_squared_error: 1.3605 - y2_output_root_mean_squared_error: 1.9624 - val_loss: 6.0564 - val_y1_output_loss: 1.8250 - val_y2_output_loss: 4.1040 - val_y1_output_root_mean_squared_error: 1.3701 - val_y2_output_root_mean_squared_error: 2.0443
# Epoch 54/500
# 614/614 [==============================] - 0s 146us/sample - loss: 5.3924 - y1_output_loss: 1.7110 - y2_output_loss: 3.6483 - y1_output_root_mean_squared_error: 1.3140 - y2_output_root_mean_squared_error: 1.9147 - val_loss: 5.6702 - val_y1_output_loss: 1.4528 - val_y2_output_loss: 4.2246 - val_y1_output_root_mean_squared_error: 1.2063 - val_y2_output_root_mean_squared_error: 2.0531
# Epoch 55/500
# 614/614 [==============================] - 0s 144us/sample - loss: 5.8775 - y1_output_loss: 1.5931 - y2_output_loss: 4.2424 - y1_output_root_mean_squared_error: 1.2640 - y2_output_root_mean_squared_error: 2.0688 - val_loss: 6.2990 - val_y1_output_loss: 1.7367 - val_y2_output_loss: 4.4743 - val_y1_output_root_mean_squared_error: 1.3228 - val_y2_output_root_mean_squared_error: 2.1329
# Epoch 56/500
# 614/614 [==============================] - 0s 184us/sample - loss: 4.9301 - y1_output_loss: 1.5696 - y2_output_loss: 3.4741 - y1_output_root_mean_squared_error: 1.2311 - y2_output_root_mean_squared_error: 1.8478 - val_loss: 24.1523 - val_y1_output_loss: 6.2952 - val_y2_output_loss: 18.0160 - val_y1_output_root_mean_squared_error: 2.4863 - val_y2_output_root_mean_squared_error: 4.2392
# Epoch 57/500
# 614/614 [==============================] - 0s 151us/sample - loss: 5.3141 - y1_output_loss: 1.7225 - y2_output_loss: 3.6648 - y1_output_root_mean_squared_error: 1.3073 - y2_output_root_mean_squared_error: 1.8987 - val_loss: 21.5162 - val_y1_output_loss: 7.1740 - val_y2_output_loss: 14.1554 - val_y1_output_root_mean_squared_error: 2.6813 - val_y2_output_root_mean_squared_error: 3.7851
# Epoch 58/500
# 614/614 [==============================] - 0s 151us/sample - loss: 4.9082 - y1_output_loss: 1.4773 - y2_output_loss: 3.4845 - y1_output_root_mean_squared_error: 1.2201 - y2_output_root_mean_squared_error: 1.8492 - val_loss: 11.3534 - val_y1_output_loss: 1.4152 - val_y2_output_loss: 10.1649 - val_y1_output_root_mean_squared_error: 1.1847 - val_y2_output_root_mean_squared_error: 3.1543
# Epoch 59/500
# 614/614 [==============================] - 0s 147us/sample - loss: 5.1219 - y1_output_loss: 1.5140 - y2_output_loss: 3.5646 - y1_output_root_mean_squared_error: 1.2357 - y2_output_root_mean_squared_error: 1.8960 - val_loss: 5.2105 - val_y1_output_loss: 1.4426 - val_y2_output_loss: 3.6527 - val_y1_output_root_mean_squared_error: 1.2097 - val_y2_output_root_mean_squared_error: 1.9357
# Epoch 60/500
# 614/614 [==============================] - 0s 147us/sample - loss: 4.1941 - y1_output_loss: 1.1499 - y2_output_loss: 3.0685 - y1_output_root_mean_squared_error: 1.0723 - y2_output_root_mean_squared_error: 1.7448 - val_loss: 6.7010 - val_y1_output_loss: 1.6804 - val_y2_output_loss: 5.1904 - val_y1_output_root_mean_squared_error: 1.2909 - val_y2_output_root_mean_squared_error: 2.2438
# Epoch 61/500
# 614/614 [==============================] - 0s 148us/sample - loss: 6.0152 - y1_output_loss: 1.6618 - y2_output_loss: 4.4586 - y1_output_root_mean_squared_error: 1.2867 - y2_output_root_mean_squared_error: 2.0880 - val_loss: 18.9277 - val_y1_output_loss: 3.8324 - val_y2_output_loss: 14.8906 - val_y1_output_root_mean_squared_error: 1.9712 - val_y2_output_root_mean_squared_error: 3.8784
# Epoch 62/500
# 614/614 [==============================] - 0s 146us/sample - loss: 6.8353 - y1_output_loss: 2.0011 - y2_output_loss: 4.7824 - y1_output_root_mean_squared_error: 1.4181 - y2_output_root_mean_squared_error: 2.1964 - val_loss: 4.6840 - val_y1_output_loss: 0.9890 - val_y2_output_loss: 3.6419 - val_y1_output_root_mean_squared_error: 1.0035 - val_y2_output_root_mean_squared_error: 1.9175
# Epoch 63/500
# 614/614 [==============================] - 0s 144us/sample - loss: 4.2756 - y1_output_loss: 1.2501 - y2_output_loss: 2.9932 - y1_output_root_mean_squared_error: 1.1230 - y2_output_root_mean_squared_error: 1.7363 - val_loss: 9.1563 - val_y1_output_loss: 3.3977 - val_y2_output_loss: 6.1566 - val_y1_output_root_mean_squared_error: 1.7832 - val_y2_output_root_mean_squared_error: 2.4447
# Epoch 64/500
# 614/614 [==============================] - 0s 146us/sample - loss: 4.5369 - y1_output_loss: 1.1631 - y2_output_loss: 3.3368 - y1_output_root_mean_squared_error: 1.0824 - y2_output_root_mean_squared_error: 1.8345 - val_loss: 3.9577 - val_y1_output_loss: 0.8287 - val_y2_output_loss: 3.0545 - val_y1_output_root_mean_squared_error: 0.9197 - val_y2_output_root_mean_squared_error: 1.7641
# Epoch 65/500
# 614/614 [==============================] - 0s 149us/sample - loss: 5.3686 - y1_output_loss: 1.4402 - y2_output_loss: 4.0502 - y1_output_root_mean_squared_error: 1.1989 - y2_output_root_mean_squared_error: 1.9827 - val_loss: 38.2070 - val_y1_output_loss: 5.9522 - val_y2_output_loss: 32.8663 - val_y1_output_root_mean_squared_error: 2.4326 - val_y2_output_root_mean_squared_error: 5.6824
# Epoch 66/500
# 614/614 [==============================] - 0s 149us/sample - loss: 4.8413 - y1_output_loss: 1.3684 - y2_output_loss: 3.4416 - y1_output_root_mean_squared_error: 1.1739 - y2_output_root_mean_squared_error: 1.8610 - val_loss: 4.3008 - val_y1_output_loss: 0.7804 - val_y2_output_loss: 3.5380 - val_y1_output_root_mean_squared_error: 0.8971 - val_y2_output_root_mean_squared_error: 1.8698
# Epoch 67/500
# 614/614 [==============================] - 0s 150us/sample - loss: 3.8043 - y1_output_loss: 0.9571 - y2_output_loss: 2.9190 - y1_output_root_mean_squared_error: 0.9674 - y2_output_root_mean_squared_error: 1.6937 - val_loss: 12.8934 - val_y1_output_loss: 4.0206 - val_y2_output_loss: 9.3465 - val_y1_output_root_mean_squared_error: 1.9656 - val_y2_output_root_mean_squared_error: 3.0050
# Epoch 68/500
# 614/614 [==============================] - 0s 143us/sample - loss: 6.2505 - y1_output_loss: 1.6777 - y2_output_loss: 4.6799 - y1_output_root_mean_squared_error: 1.2768 - y2_output_root_mean_squared_error: 2.1495 - val_loss: 66.8348 - val_y1_output_loss: 27.1076 - val_y2_output_loss: 44.2859 - val_y1_output_root_mean_squared_error: 5.0197 - val_y2_output_root_mean_squared_error: 6.4527
# Epoch 69/500
# 614/614 [==============================] - 0s 145us/sample - loss: 6.6866 - y1_output_loss: 2.1637 - y2_output_loss: 4.4974 - y1_output_root_mean_squared_error: 1.4754 - y2_output_root_mean_squared_error: 2.1237 - val_loss: 7.7068 - val_y1_output_loss: 2.2855 - val_y2_output_loss: 5.1784 - val_y1_output_root_mean_squared_error: 1.5279 - val_y2_output_root_mean_squared_error: 2.3178
# Epoch 70/500
# 614/614 [==============================] - 0s 151us/sample - loss: 3.3733 - y1_output_loss: 0.7952 - y2_output_loss: 2.5710 - y1_output_root_mean_squared_error: 0.8923 - y2_output_root_mean_squared_error: 1.6053 - val_loss: 5.6019 - val_y1_output_loss: 1.3893 - val_y2_output_loss: 4.3231 - val_y1_output_root_mean_squared_error: 1.1651 - val_y2_output_root_mean_squared_error: 2.0602
# Epoch 71/500
# 614/614 [==============================] - 0s 153us/sample - loss: 4.5175 - y1_output_loss: 1.2329 - y2_output_loss: 3.2657 - y1_output_root_mean_squared_error: 1.1077 - y2_output_root_mean_squared_error: 1.8140 - val_loss: 4.5168 - val_y1_output_loss: 0.6600 - val_y2_output_loss: 3.8939 - val_y1_output_root_mean_squared_error: 0.8219 - val_y2_output_root_mean_squared_error: 1.9599
# Epoch 72/500
# 614/614 [==============================] - 0s 149us/sample - loss: 4.3469 - y1_output_loss: 1.1266 - y2_output_loss: 3.2395 - y1_output_root_mean_squared_error: 1.0653 - y2_output_root_mean_squared_error: 1.7922 - val_loss: 5.0253 - val_y1_output_loss: 0.7455 - val_y2_output_loss: 4.3545 - val_y1_output_root_mean_squared_error: 0.8757 - val_y2_output_root_mean_squared_error: 2.0636
# Epoch 73/500
# 614/614 [==============================] - 0s 149us/sample - loss: 5.7407 - y1_output_loss: 1.4765 - y2_output_loss: 4.2859 - y1_output_root_mean_squared_error: 1.2201 - y2_output_root_mean_squared_error: 2.0621 - val_loss: 6.1205 - val_y1_output_loss: 1.1657 - val_y2_output_loss: 4.8960 - val_y1_output_root_mean_squared_error: 1.0926 - val_y2_output_root_mean_squared_error: 2.2196
# Epoch 74/500
# 614/614 [==============================] - 0s 147us/sample - loss: 3.2402 - y1_output_loss: 0.7854 - y2_output_loss: 2.4772 - y1_output_root_mean_squared_error: 0.8884 - y2_output_root_mean_squared_error: 1.5656 - val_loss: 5.5934 - val_y1_output_loss: 0.9296 - val_y2_output_loss: 4.6442 - val_y1_output_root_mean_squared_error: 0.9703 - val_y2_output_root_mean_squared_error: 2.1568
# Epoch 75/500
# 614/614 [==============================] - 0s 147us/sample - loss: 3.2545 - y1_output_loss: 0.7769 - y2_output_loss: 2.4766 - y1_output_root_mean_squared_error: 0.8845 - y2_output_root_mean_squared_error: 1.5723 - val_loss: 8.0455 - val_y1_output_loss: 1.3765 - val_y2_output_loss: 6.9297 - val_y1_output_root_mean_squared_error: 1.1708 - val_y2_output_root_mean_squared_error: 2.5836
# Epoch 76/500
# 614/614 [==============================] - 0s 147us/sample - loss: 3.6666 - y1_output_loss: 0.8257 - y2_output_loss: 2.8116 - y1_output_root_mean_squared_error: 0.9124 - y2_output_root_mean_squared_error: 1.6835 - val_loss: 3.8536 - val_y1_output_loss: 0.4929 - val_y2_output_loss: 3.3857 - val_y1_output_root_mean_squared_error: 0.7137 - val_y2_output_root_mean_squared_error: 1.8287
# Epoch 77/500
# 614/614 [==============================] - 0s 156us/sample - loss: 3.6088 - y1_output_loss: 0.8990 - y2_output_loss: 2.7130 - y1_output_root_mean_squared_error: 0.9490 - y2_output_root_mean_squared_error: 1.6456 - val_loss: 8.9102 - val_y1_output_loss: 1.4654 - val_y2_output_loss: 7.2288 - val_y1_output_root_mean_squared_error: 1.2218 - val_y2_output_root_mean_squared_error: 2.7235
# Epoch 78/500
# 614/614 [==============================] - 0s 147us/sample - loss: 4.8506 - y1_output_loss: 1.1774 - y2_output_loss: 3.6814 - y1_output_root_mean_squared_error: 1.0854 - y2_output_root_mean_squared_error: 1.9164 - val_loss: 5.6469 - val_y1_output_loss: 1.2541 - val_y2_output_loss: 4.5910 - val_y1_output_root_mean_squared_error: 1.1156 - val_y2_output_root_mean_squared_error: 2.0982
# Epoch 79/500
# 614/614 [==============================] - 0s 143us/sample - loss: 3.6191 - y1_output_loss: 1.0078 - y2_output_loss: 2.6030 - y1_output_root_mean_squared_error: 1.0064 - y2_output_root_mean_squared_error: 1.6144 - val_loss: 3.9361 - val_y1_output_loss: 0.7102 - val_y2_output_loss: 3.1601 - val_y1_output_root_mean_squared_error: 0.8579 - val_y2_output_root_mean_squared_error: 1.7889
# Epoch 80/500
# 614/614 [==============================] - 0s 143us/sample - loss: 3.2379 - y1_output_loss: 0.6604 - y2_output_loss: 2.6159 - y1_output_root_mean_squared_error: 0.8025 - y2_output_root_mean_squared_error: 1.6106 - val_loss: 7.7368 - val_y1_output_loss: 2.5887 - val_y2_output_loss: 5.2050 - val_y1_output_root_mean_squared_error: 1.6198 - val_y2_output_root_mean_squared_error: 2.2612
# Epoch 81/500
# 614/614 [==============================] - 0s 147us/sample - loss: 4.2493 - y1_output_loss: 1.0732 - y2_output_loss: 3.1509 - y1_output_root_mean_squared_error: 1.0408 - y2_output_root_mean_squared_error: 1.7794 - val_loss: 4.8464 - val_y1_output_loss: 1.1258 - val_y2_output_loss: 3.6074 - val_y1_output_root_mean_squared_error: 1.0776 - val_y2_output_root_mean_squared_error: 1.9197
# Epoch 82/500
# 614/614 [==============================] - 0s 148us/sample - loss: 3.8082 - y1_output_loss: 0.8786 - y2_output_loss: 2.8982 - y1_output_root_mean_squared_error: 0.9409 - y2_output_root_mean_squared_error: 1.7096 - val_loss: 3.4604 - val_y1_output_loss: 0.5183 - val_y2_output_loss: 2.9487 - val_y1_output_root_mean_squared_error: 0.7313 - val_y2_output_root_mean_squared_error: 1.7104
# Epoch 83/500
# 614/614 [==============================] - 0s 146us/sample - loss: 3.9293 - y1_output_loss: 0.9428 - y2_output_loss: 2.9776 - y1_output_root_mean_squared_error: 0.9755 - y2_output_root_mean_squared_error: 1.7256 - val_loss: 3.5474 - val_y1_output_loss: 0.6383 - val_y2_output_loss: 2.8849 - val_y1_output_root_mean_squared_error: 0.8093 - val_y2_output_root_mean_squared_error: 1.7007
# Epoch 84/500
# 614/614 [==============================] - 0s 146us/sample - loss: 2.7356 - y1_output_loss: 0.5905 - y2_output_loss: 2.1409 - y1_output_root_mean_squared_error: 0.7656 - y2_output_root_mean_squared_error: 1.4661 - val_loss: 5.3843 - val_y1_output_loss: 0.6526 - val_y2_output_loss: 4.6237 - val_y1_output_root_mean_squared_error: 0.8206 - val_y2_output_root_mean_squared_error: 2.1705
# Epoch 85/500
# 614/614 [==============================] - 0s 147us/sample - loss: 3.1592 - y1_output_loss: 0.6976 - y2_output_loss: 2.4488 - y1_output_root_mean_squared_error: 0.8353 - y2_output_root_mean_squared_error: 1.5689 - val_loss: 4.5436 - val_y1_output_loss: 1.5230 - val_y2_output_loss: 3.2832 - val_y1_output_root_mean_squared_error: 1.2044 - val_y2_output_root_mean_squared_error: 1.7587
# Epoch 86/500
# 614/614 [==============================] - 0s 148us/sample - loss: 5.8461 - y1_output_loss: 1.9276 - y2_output_loss: 3.9033 - y1_output_root_mean_squared_error: 1.3842 - y2_output_root_mean_squared_error: 1.9824 - val_loss: 12.4206 - val_y1_output_loss: 5.1583 - val_y2_output_loss: 7.6840 - val_y1_output_root_mean_squared_error: 2.2257 - val_y2_output_root_mean_squared_error: 2.7326
# Epoch 87/500
# 614/614 [==============================] - 0s 146us/sample - loss: 4.0536 - y1_output_loss: 0.9940 - y2_output_loss: 3.0574 - y1_output_root_mean_squared_error: 1.0011 - y2_output_root_mean_squared_error: 1.7468 - val_loss: 10.2842 - val_y1_output_loss: 1.5043 - val_y2_output_loss: 9.0631 - val_y1_output_root_mean_squared_error: 1.2242 - val_y2_output_root_mean_squared_error: 2.9640
# Epoch 88/500
# 614/614 [==============================] - 0s 146us/sample - loss: 3.1850 - y1_output_loss: 0.8370 - y2_output_loss: 2.3532 - y1_output_root_mean_squared_error: 0.9080 - y2_output_root_mean_squared_error: 1.5364 - val_loss: 4.9577 - val_y1_output_loss: 1.5612 - val_y2_output_loss: 3.4980 - val_y1_output_root_mean_squared_error: 1.2462 - val_y2_output_root_mean_squared_error: 1.8452
# Epoch 89/500
# 614/614 [==============================] - 0s 156us/sample - loss: 3.4756 - y1_output_loss: 0.9132 - y2_output_loss: 2.5465 - y1_output_root_mean_squared_error: 0.9580 - y2_output_root_mean_squared_error: 1.5994 - val_loss: 3.4198 - val_y1_output_loss: 0.7005 - val_y2_output_loss: 2.8073 - val_y1_output_root_mean_squared_error: 0.8399 - val_y2_output_root_mean_squared_error: 1.6475
# Epoch 90/500
# 614/614 [==============================] - 0s 143us/sample - loss: 2.7306 - y1_output_loss: 0.5718 - y2_output_loss: 2.1486 - y1_output_root_mean_squared_error: 0.7550 - y2_output_root_mean_squared_error: 1.4699 - val_loss: 4.1138 - val_y1_output_loss: 0.8205 - val_y2_output_loss: 3.4463 - val_y1_output_root_mean_squared_error: 0.8842 - val_y2_output_root_mean_squared_error: 1.8254
# Epoch 91/500
# 614/614 [==============================] - 0s 149us/sample - loss: 2.6937 - y1_output_loss: 0.5998 - y2_output_loss: 2.0808 - y1_output_root_mean_squared_error: 0.7762 - y2_output_root_mean_squared_error: 1.4461 - val_loss: 3.7738 - val_y1_output_loss: 0.4726 - val_y2_output_loss: 3.4245 - val_y1_output_root_mean_squared_error: 0.6971 - val_y2_output_root_mean_squared_error: 1.8132
# Epoch 92/500
# 614/614 [==============================] - 0s 161us/sample - loss: 2.6552 - y1_output_loss: 0.5610 - y2_output_loss: 2.0745 - y1_output_root_mean_squared_error: 0.7510 - y2_output_root_mean_squared_error: 1.4461 - val_loss: 4.3823 - val_y1_output_loss: 0.7444 - val_y2_output_loss: 3.7838 - val_y1_output_root_mean_squared_error: 0.8552 - val_y2_output_root_mean_squared_error: 1.9107
# Epoch 93/500
# 614/614 [==============================] - 0s 191us/sample - loss: 4.8697 - y1_output_loss: 1.3214 - y2_output_loss: 3.6461 - y1_output_root_mean_squared_error: 1.1532 - y2_output_root_mean_squared_error: 1.8815 - val_loss: 30.2068 - val_y1_output_loss: 4.1877 - val_y2_output_loss: 27.0979 - val_y1_output_root_mean_squared_error: 2.0152 - val_y2_output_root_mean_squared_error: 5.1133
# Epoch 94/500
# 614/614 [==============================] - 0s 149us/sample - loss: 2.9565 - y1_output_loss: 0.6377 - y2_output_loss: 2.2916 - y1_output_root_mean_squared_error: 0.8020 - y2_output_root_mean_squared_error: 1.5210 - val_loss: 3.1695 - val_y1_output_loss: 0.5074 - val_y2_output_loss: 2.6550 - val_y1_output_root_mean_squared_error: 0.7243 - val_y2_output_root_mean_squared_error: 1.6263
# Epoch 95/500
# 614/614 [==============================] - 0s 160us/sample - loss: 4.0229 - y1_output_loss: 0.8836 - y2_output_loss: 3.1511 - y1_output_root_mean_squared_error: 0.9394 - y2_output_root_mean_squared_error: 1.7721 - val_loss: 4.6091 - val_y1_output_loss: 1.0392 - val_y2_output_loss: 3.4545 - val_y1_output_root_mean_squared_error: 1.0281 - val_y2_output_root_mean_squared_error: 1.8847
# Epoch 96/500
# 614/614 [==============================] - 0s 156us/sample - loss: 2.9201 - y1_output_loss: 0.6825 - y2_output_loss: 2.2172 - y1_output_root_mean_squared_error: 0.8276 - y2_output_root_mean_squared_error: 1.4950 - val_loss: 2.9155 - val_y1_output_loss: 0.4231 - val_y2_output_loss: 2.4788 - val_y1_output_root_mean_squared_error: 0.6594 - val_y2_output_root_mean_squared_error: 1.5750
# Epoch 97/500
# 614/614 [==============================] - 0s 151us/sample - loss: 3.1405 - y1_output_loss: 0.6182 - y2_output_loss: 2.4942 - y1_output_root_mean_squared_error: 0.7890 - y2_output_root_mean_squared_error: 1.5868 - val_loss: 2.8859 - val_y1_output_loss: 0.6136 - val_y2_output_loss: 2.3046 - val_y1_output_root_mean_squared_error: 0.7939 - val_y2_output_root_mean_squared_error: 1.5019
# Epoch 98/500
# 614/614 [==============================] - 0s 153us/sample - loss: 2.8631 - y1_output_loss: 0.6161 - y2_output_loss: 2.2290 - y1_output_root_mean_squared_error: 0.7840 - y2_output_root_mean_squared_error: 1.4995 - val_loss: 4.1333 - val_y1_output_loss: 0.4935 - val_y2_output_loss: 3.8317 - val_y1_output_root_mean_squared_error: 0.7026 - val_y2_output_root_mean_squared_error: 1.9078
# Epoch 99/500
# 614/614 [==============================] - 0s 164us/sample - loss: 2.4830 - y1_output_loss: 0.5325 - y2_output_loss: 1.9277 - y1_output_root_mean_squared_error: 0.7327 - y2_output_root_mean_squared_error: 1.3950 - val_loss: 3.3057 - val_y1_output_loss: 0.7914 - val_y2_output_loss: 2.5039 - val_y1_output_root_mean_squared_error: 0.8994 - val_y2_output_root_mean_squared_error: 1.5801
# Epoch 100/500
# 614/614 [==============================] - 0s 151us/sample - loss: 2.7767 - y1_output_loss: 0.7502 - y2_output_loss: 2.0712 - y1_output_root_mean_squared_error: 0.8534 - y2_output_root_mean_squared_error: 1.4312 - val_loss: 9.0914 - val_y1_output_loss: 3.1349 - val_y2_output_loss: 6.0496 - val_y1_output_root_mean_squared_error: 1.7538 - val_y2_output_root_mean_squared_error: 2.4527
# Epoch 101/500
# 614/614 [==============================] - 0s 150us/sample - loss: 3.2602 - y1_output_loss: 0.8186 - y2_output_loss: 2.4544 - y1_output_root_mean_squared_error: 0.9064 - y2_output_root_mean_squared_error: 1.5616 - val_loss: 3.5601 - val_y1_output_loss: 0.6680 - val_y2_output_loss: 2.9319 - val_y1_output_root_mean_squared_error: 0.8071 - val_y2_output_root_mean_squared_error: 1.7055
# Epoch 102/500
# 614/614 [==============================] - 0s 154us/sample - loss: 2.4494 - y1_output_loss: 0.5664 - y2_output_loss: 1.8905 - y1_output_root_mean_squared_error: 0.7531 - y2_output_root_mean_squared_error: 1.3719 - val_loss: 2.8315 - val_y1_output_loss: 0.4463 - val_y2_output_loss: 2.4392 - val_y1_output_root_mean_squared_error: 0.6724 - val_y2_output_root_mean_squared_error: 1.5425
# Epoch 103/500
# 614/614 [==============================] - 0s 151us/sample - loss: 4.5156 - y1_output_loss: 1.0435 - y2_output_loss: 3.4927 - y1_output_root_mean_squared_error: 1.0253 - y2_output_root_mean_squared_error: 1.8613 - val_loss: 13.8656 - val_y1_output_loss: 2.1740 - val_y2_output_loss: 12.1727 - val_y1_output_root_mean_squared_error: 1.4434 - val_y2_output_root_mean_squared_error: 3.4325
# Epoch 104/500
# 614/614 [==============================] - 0s 154us/sample - loss: 2.2829 - y1_output_loss: 0.5038 - y2_output_loss: 1.7705 - y1_output_root_mean_squared_error: 0.7099 - y2_output_root_mean_squared_error: 1.3338 - val_loss: 4.0955 - val_y1_output_loss: 0.8206 - val_y2_output_loss: 3.2054 - val_y1_output_root_mean_squared_error: 0.9112 - val_y2_output_root_mean_squared_error: 1.8070
# Epoch 105/500
# 614/614 [==============================] - 0s 154us/sample - loss: 2.3220 - y1_output_loss: 0.5006 - y2_output_loss: 1.8197 - y1_output_root_mean_squared_error: 0.7066 - y2_output_root_mean_squared_error: 1.3501 - val_loss: 2.6825 - val_y1_output_loss: 0.4352 - val_y2_output_loss: 2.2791 - val_y1_output_root_mean_squared_error: 0.6692 - val_y2_output_root_mean_squared_error: 1.4949
# Epoch 106/500
# 614/614 [==============================] - 0s 149us/sample - loss: 2.4195 - y1_output_loss: 0.4527 - y2_output_loss: 1.9498 - y1_output_root_mean_squared_error: 0.6735 - y2_output_root_mean_squared_error: 1.4021 - val_loss: 3.5188 - val_y1_output_loss: 0.8605 - val_y2_output_loss: 2.7565 - val_y1_output_root_mean_squared_error: 0.9154 - val_y2_output_root_mean_squared_error: 1.6374
# Epoch 107/500
# 614/614 [==============================] - 0s 164us/sample - loss: 2.8611 - y1_output_loss: 0.6211 - y2_output_loss: 2.2828 - y1_output_root_mean_squared_error: 0.7880 - y2_output_root_mean_squared_error: 1.4967 - val_loss: 3.5551 - val_y1_output_loss: 1.1084 - val_y2_output_loss: 2.6719 - val_y1_output_root_mean_squared_error: 1.0332 - val_y2_output_root_mean_squared_error: 1.5772
# Epoch 108/500
# 614/614 [==============================] - 0s 151us/sample - loss: 2.9245 - y1_output_loss: 0.6458 - y2_output_loss: 2.2564 - y1_output_root_mean_squared_error: 0.8058 - y2_output_root_mean_squared_error: 1.5084 - val_loss: 2.4575 - val_y1_output_loss: 0.4069 - val_y2_output_loss: 2.1322 - val_y1_output_root_mean_squared_error: 0.6447 - val_y2_output_root_mean_squared_error: 1.4289
# Epoch 109/500
# 614/614 [==============================] - 0s 157us/sample - loss: 2.9161 - y1_output_loss: 0.6342 - y2_output_loss: 2.2632 - y1_output_root_mean_squared_error: 0.7982 - y2_output_root_mean_squared_error: 1.5096 - val_loss: 4.5916 - val_y1_output_loss: 1.3005 - val_y2_output_loss: 3.5191 - val_y1_output_root_mean_squared_error: 1.1251 - val_y2_output_root_mean_squared_error: 1.8237
# Epoch 110/500
# 614/614 [==============================] - 0s 159us/sample - loss: 2.2476 - y1_output_loss: 0.4754 - y2_output_loss: 1.7630 - y1_output_root_mean_squared_error: 0.6897 - y2_output_root_mean_squared_error: 1.3311 - val_loss: 2.6754 - val_y1_output_loss: 0.3980 - val_y2_output_loss: 2.3932 - val_y1_output_root_mean_squared_error: 0.6364 - val_y2_output_root_mean_squared_error: 1.5068
# Epoch 111/500
# 614/614 [==============================] - 0s 166us/sample - loss: 2.3884 - y1_output_loss: 0.5269 - y2_output_loss: 1.8810 - y1_output_root_mean_squared_error: 0.7276 - y2_output_root_mean_squared_error: 1.3634 - val_loss: 4.2427 - val_y1_output_loss: 1.4229 - val_y2_output_loss: 2.8194 - val_y1_output_root_mean_squared_error: 1.1893 - val_y2_output_root_mean_squared_error: 1.6817
# Epoch 112/500
# 614/614 [==============================] - 0s 173us/sample - loss: 2.5203 - y1_output_loss: 0.6329 - y2_output_loss: 1.8717 - y1_output_root_mean_squared_error: 0.7956 - y2_output_root_mean_squared_error: 1.3738 - val_loss: 2.7951 - val_y1_output_loss: 0.6238 - val_y2_output_loss: 2.3043 - val_y1_output_root_mean_squared_error: 0.7941 - val_y2_output_root_mean_squared_error: 1.4712
# Epoch 113/500
# 614/614 [==============================] - 0s 155us/sample - loss: 2.1660 - y1_output_loss: 0.4619 - y2_output_loss: 1.7148 - y1_output_root_mean_squared_error: 0.6803 - y2_output_root_mean_squared_error: 1.3050 - val_loss: 4.7330 - val_y1_output_loss: 0.4522 - val_y2_output_loss: 4.3783 - val_y1_output_root_mean_squared_error: 0.6828 - val_y2_output_root_mean_squared_error: 2.0656
# Epoch 114/500
# 614/614 [==============================] - 0s 153us/sample - loss: 3.8376 - y1_output_loss: 1.1230 - y2_output_loss: 2.6900 - y1_output_root_mean_squared_error: 1.0622 - y2_output_root_mean_squared_error: 1.6460 - val_loss: 2.8229 - val_y1_output_loss: 0.4883 - val_y2_output_loss: 2.4215 - val_y1_output_root_mean_squared_error: 0.7010 - val_y2_output_root_mean_squared_error: 1.5269
# Epoch 115/500
# 614/614 [==============================] - 0s 150us/sample - loss: 2.2324 - y1_output_loss: 0.5128 - y2_output_loss: 1.7142 - y1_output_root_mean_squared_error: 0.7119 - y2_output_root_mean_squared_error: 1.3136 - val_loss: 3.1711 - val_y1_output_loss: 0.8713 - val_y2_output_loss: 2.3729 - val_y1_output_root_mean_squared_error: 0.9320 - val_y2_output_root_mean_squared_error: 1.5174
# Epoch 116/500
# 614/614 [==============================] - 0s 166us/sample - loss: 2.7932 - y1_output_loss: 0.6557 - y2_output_loss: 2.1734 - y1_output_root_mean_squared_error: 0.8081 - y2_output_root_mean_squared_error: 1.4630 - val_loss: 8.7677 - val_y1_output_loss: 3.2289 - val_y2_output_loss: 5.8598 - val_y1_output_root_mean_squared_error: 1.7740 - val_y2_output_root_mean_squared_error: 2.3708
# Epoch 117/500
# 614/614 [==============================] - 0s 148us/sample - loss: 2.8368 - y1_output_loss: 0.6311 - y2_output_loss: 2.2055 - y1_output_root_mean_squared_error: 0.7913 - y2_output_root_mean_squared_error: 1.4868 - val_loss: 2.5607 - val_y1_output_loss: 0.4942 - val_y2_output_loss: 2.1169 - val_y1_output_root_mean_squared_error: 0.7025 - val_y2_output_root_mean_squared_error: 1.4378
# Epoch 118/500
# 614/614 [==============================] - 0s 146us/sample - loss: 2.0478 - y1_output_loss: 0.5324 - y2_output_loss: 1.5988 - y1_output_root_mean_squared_error: 0.7243 - y2_output_root_mean_squared_error: 1.2342 - val_loss: 11.9669 - val_y1_output_loss: 2.2686 - val_y2_output_loss: 9.5562 - val_y1_output_root_mean_squared_error: 1.5164 - val_y2_output_root_mean_squared_error: 3.1092
# Epoch 119/500
# 614/614 [==============================] - 0s 149us/sample - loss: 2.3093 - y1_output_loss: 0.4453 - y2_output_loss: 1.8599 - y1_output_root_mean_squared_error: 0.6701 - y2_output_root_mean_squared_error: 1.3639 - val_loss: 7.4352 - val_y1_output_loss: 0.6144 - val_y2_output_loss: 7.1506 - val_y1_output_root_mean_squared_error: 0.7823 - val_y2_output_root_mean_squared_error: 2.6121
# Epoch 120/500
# 614/614 [==============================] - 0s 150us/sample - loss: 1.9934 - y1_output_loss: 0.4667 - y2_output_loss: 1.5145 - y1_output_root_mean_squared_error: 0.6852 - y2_output_root_mean_squared_error: 1.2345 - val_loss: 2.6903 - val_y1_output_loss: 0.4915 - val_y2_output_loss: 2.3225 - val_y1_output_root_mean_squared_error: 0.6970 - val_y2_output_root_mean_squared_error: 1.4848
# Epoch 121/500
# ...
# Epoch 461/500
# 614/614 [==============================] - 0s 149us/sample - loss: 0.2970 - y1_output_loss: 0.0997 - y2_output_loss: 0.1953 - y1_output_root_mean_squared_error: 0.3171 - y2_output_root_mean_squared_error: 0.4433 - val_loss: 1.2773 - val_y1_output_loss: 0.2128 - val_y2_output_loss: 1.0947 - val_y1_output_root_mean_squared_error: 0.4593 - val_y2_output_root_mean_squared_error: 1.0327
# Epoch 462/500
# 614/614 [==============================] - 0s 151us/sample - loss: 0.3523 - y1_output_loss: 0.1277 - y2_output_loss: 0.2236 - y1_output_root_mean_squared_error: 0.3589 - y2_output_root_mean_squared_error: 0.4727 - val_loss: 0.8905 - val_y1_output_loss: 0.2023 - val_y2_output_loss: 0.7096 - val_y1_output_root_mean_squared_error: 0.4514 - val_y2_output_root_mean_squared_error: 0.8287
# Epoch 463/500
# 614/614 [==============================] - 0s 148us/sample - loss: 0.3241 - y1_output_loss: 0.1090 - y2_output_loss: 0.2129 - y1_output_root_mean_squared_error: 0.3306 - y2_output_root_mean_squared_error: 0.4635 - val_loss: 0.9547 - val_y1_output_loss: 0.2684 - val_y2_output_loss: 0.6899 - val_y1_output_root_mean_squared_error: 0.5133 - val_y2_output_root_mean_squared_error: 0.8314
# Epoch 464/500
# 614/614 [==============================] - 0s 146us/sample - loss: 0.4461 - y1_output_loss: 0.1323 - y2_output_loss: 0.3103 - y1_output_root_mean_squared_error: 0.3649 - y2_output_root_mean_squared_error: 0.5594 - val_loss: 0.7543 - val_y1_output_loss: 0.1784 - val_y2_output_loss: 0.5913 - val_y1_output_root_mean_squared_error: 0.4240 - val_y2_output_root_mean_squared_error: 0.7579
# Epoch 465/500
# 614/614 [==============================] - 0s 144us/sample - loss: 0.3775 - y1_output_loss: 0.1322 - y2_output_loss: 0.2424 - y1_output_root_mean_squared_error: 0.3646 - y2_output_root_mean_squared_error: 0.4945 - val_loss: 0.8479 - val_y1_output_loss: 0.2117 - val_y2_output_loss: 0.6666 - val_y1_output_root_mean_squared_error: 0.4586 - val_y2_output_root_mean_squared_error: 0.7985
# Epoch 466/500
# 614/614 [==============================] - 0s 151us/sample - loss: 0.2952 - y1_output_loss: 0.1081 - y2_output_loss: 0.1877 - y1_output_root_mean_squared_error: 0.3301 - y2_output_root_mean_squared_error: 0.4315 - val_loss: 0.8197 - val_y1_output_loss: 0.1884 - val_y2_output_loss: 0.6586 - val_y1_output_root_mean_squared_error: 0.4342 - val_y2_output_root_mean_squared_error: 0.7945
# Epoch 467/500
# 614/614 [==============================] - 0s 153us/sample - loss: 0.3830 - y1_output_loss: 0.1216 - y2_output_loss: 0.2604 - y1_output_root_mean_squared_error: 0.3497 - y2_output_root_mean_squared_error: 0.5105 - val_loss: 0.8718 - val_y1_output_loss: 0.1870 - val_y2_output_loss: 0.7090 - val_y1_output_root_mean_squared_error: 0.4338 - val_y2_output_root_mean_squared_error: 0.8268
# Epoch 468/500
# 614/614 [==============================] - 0s 146us/sample - loss: 0.3347 - y1_output_loss: 0.1142 - y2_output_loss: 0.2194 - y1_output_root_mean_squared_error: 0.3376 - y2_output_root_mean_squared_error: 0.4699 - val_loss: 1.0593 - val_y1_output_loss: 0.2867 - val_y2_output_loss: 0.8065 - val_y1_output_root_mean_squared_error: 0.5328 - val_y2_output_root_mean_squared_error: 0.8806
# Epoch 469/500
# 614/614 [==============================] - 0s 145us/sample - loss: 0.3297 - y1_output_loss: 0.1113 - y2_output_loss: 0.2174 - y1_output_root_mean_squared_error: 0.3344 - y2_output_root_mean_squared_error: 0.4668 - val_loss: 0.8324 - val_y1_output_loss: 0.2338 - val_y2_output_loss: 0.6323 - val_y1_output_root_mean_squared_error: 0.4793 - val_y2_output_root_mean_squared_error: 0.7763
# Epoch 470/500
# 614/614 [==============================] - 0s 148us/sample - loss: 0.3538 - y1_output_loss: 0.1133 - y2_output_loss: 0.2382 - y1_output_root_mean_squared_error: 0.3375 - y2_output_root_mean_squared_error: 0.4898 - val_loss: 0.7651 - val_y1_output_loss: 0.1887 - val_y2_output_loss: 0.6039 - val_y1_output_root_mean_squared_error: 0.4341 - val_y2_output_root_mean_squared_error: 0.7594
# Epoch 471/500
# 614/614 [==============================] - 0s 147us/sample - loss: 0.2793 - y1_output_loss: 0.0970 - y2_output_loss: 0.1873 - y1_output_root_mean_squared_error: 0.3103 - y2_output_root_mean_squared_error: 0.4278 - val_loss: 1.8423 - val_y1_output_loss: 0.3933 - val_y2_output_loss: 1.4787 - val_y1_output_root_mean_squared_error: 0.6294 - val_y2_output_root_mean_squared_error: 1.2026
# Epoch 472/500
# 614/614 [==============================] - 0s 148us/sample - loss: 0.3712 - y1_output_loss: 0.1169 - y2_output_loss: 0.2513 - y1_output_root_mean_squared_error: 0.3434 - y2_output_root_mean_squared_error: 0.5032 - val_loss: 0.8190 - val_y1_output_loss: 0.1795 - val_y2_output_loss: 0.6545 - val_y1_output_root_mean_squared_error: 0.4266 - val_y2_output_root_mean_squared_error: 0.7981
# Epoch 473/500
# 614/614 [==============================] - 0s 146us/sample - loss: 0.3782 - y1_output_loss: 0.1258 - y2_output_loss: 0.2492 - y1_output_root_mean_squared_error: 0.3561 - y2_output_root_mean_squared_error: 0.5014 - val_loss: 0.8055 - val_y1_output_loss: 0.1928 - val_y2_output_loss: 0.6281 - val_y1_output_root_mean_squared_error: 0.4391 - val_y2_output_root_mean_squared_error: 0.7827
# Epoch 474/500
# 614/614 [==============================] - 0s 146us/sample - loss: 0.3304 - y1_output_loss: 0.1110 - y2_output_loss: 0.2186 - y1_output_root_mean_squared_error: 0.3343 - y2_output_root_mean_squared_error: 0.4676 - val_loss: 0.8779 - val_y1_output_loss: 0.1878 - val_y2_output_loss: 0.7140 - val_y1_output_root_mean_squared_error: 0.4342 - val_y2_output_root_mean_squared_error: 0.8303
# Epoch 475/500
# 614/614 [==============================] - 0s 153us/sample - loss: 0.3628 - y1_output_loss: 0.1235 - y2_output_loss: 0.2382 - y1_output_root_mean_squared_error: 0.3511 - y2_output_root_mean_squared_error: 0.4894 - val_loss: 0.8175 - val_y1_output_loss: 0.2164 - val_y2_output_loss: 0.6290 - val_y1_output_root_mean_squared_error: 0.4604 - val_y2_output_root_mean_squared_error: 0.7782
# Epoch 476/500
# 614/614 [==============================] - 0s 153us/sample - loss: 0.2772 - y1_output_loss: 0.0995 - y2_output_loss: 0.1771 - y1_output_root_mean_squared_error: 0.3158 - y2_output_root_mean_squared_error: 0.4212 - val_loss: 1.1655 - val_y1_output_loss: 0.2911 - val_y2_output_loss: 0.8962 - val_y1_output_root_mean_squared_error: 0.5341 - val_y2_output_root_mean_squared_error: 0.9382
# Epoch 477/500
# 614/614 [==============================] - 0s 148us/sample - loss: 0.3941 - y1_output_loss: 0.1243 - y2_output_loss: 0.2685 - y1_output_root_mean_squared_error: 0.3512 - y2_output_root_mean_squared_error: 0.5203 - val_loss: 0.8386 - val_y1_output_loss: 0.2225 - val_y2_output_loss: 0.6362 - val_y1_output_root_mean_squared_error: 0.4722 - val_y2_output_root_mean_squared_error: 0.7846
# Epoch 478/500
# 614/614 [==============================] - 0s 151us/sample - loss: 0.3862 - y1_output_loss: 0.1351 - y2_output_loss: 0.2906 - y1_output_root_mean_squared_error: 0.3569 - y2_output_root_mean_squared_error: 0.5088 - val_loss: 6.2477 - val_y1_output_loss: 2.0952 - val_y2_output_loss: 4.0390 - val_y1_output_root_mean_squared_error: 1.4629 - val_y2_output_root_mean_squared_error: 2.0268
# Epoch 479/500
# 614/614 [==============================] - 0s 153us/sample - loss: 0.4830 - y1_output_loss: 0.1675 - y2_output_loss: 0.3119 - y1_output_root_mean_squared_error: 0.4109 - y2_output_root_mean_squared_error: 0.5605 - val_loss: 0.9059 - val_y1_output_loss: 0.2119 - val_y2_output_loss: 0.6959 - val_y1_output_root_mean_squared_error: 0.4605 - val_y2_output_root_mean_squared_error: 0.8329
# Epoch 480/500
# 614/614 [==============================] - 0s 153us/sample - loss: 0.4275 - y1_output_loss: 0.1352 - y2_output_loss: 0.2899 - y1_output_root_mean_squared_error: 0.3691 - y2_output_root_mean_squared_error: 0.5396 - val_loss: 1.0107 - val_y1_output_loss: 0.2315 - val_y2_output_loss: 0.8051 - val_y1_output_root_mean_squared_error: 0.4761 - val_y2_output_root_mean_squared_error: 0.8854
# Epoch 481/500
# 614/614 [==============================] - 0s 151us/sample - loss: 0.2638 - y1_output_loss: 0.0991 - y2_output_loss: 0.1639 - y1_output_root_mean_squared_error: 0.3156 - y2_output_root_mean_squared_error: 0.4052 - val_loss: 0.8429 - val_y1_output_loss: 0.1693 - val_y2_output_loss: 0.6789 - val_y1_output_root_mean_squared_error: 0.4140 - val_y2_output_root_mean_squared_error: 0.8194
# Epoch 482/500
# 614/614 [==============================] - 0s 154us/sample - loss: 0.2716 - y1_output_loss: 0.1015 - y2_output_loss: 0.1691 - y1_output_root_mean_squared_error: 0.3200 - y2_output_root_mean_squared_error: 0.4113 - val_loss: 1.1407 - val_y1_output_loss: 0.2464 - val_y2_output_loss: 0.9320 - val_y1_output_root_mean_squared_error: 0.4937 - val_y2_output_root_mean_squared_error: 0.9471
# Epoch 483/500
# 614/614 [==============================] - 0s 166us/sample - loss: 0.3308 - y1_output_loss: 0.1162 - y2_output_loss: 0.2150 - y1_output_root_mean_squared_error: 0.3395 - y2_output_root_mean_squared_error: 0.4643 - val_loss: 1.2683 - val_y1_output_loss: 0.4220 - val_y2_output_loss: 0.8885 - val_y1_output_root_mean_squared_error: 0.6403 - val_y2_output_root_mean_squared_error: 0.9264
# Epoch 484/500
# 614/614 [==============================] - 0s 154us/sample - loss: 0.3189 - y1_output_loss: 0.1028 - y2_output_loss: 0.2258 - y1_output_root_mean_squared_error: 0.3214 - y2_output_root_mean_squared_error: 0.4643 - val_loss: 4.1597 - val_y1_output_loss: 0.6444 - val_y2_output_loss: 3.6556 - val_y1_output_root_mean_squared_error: 0.7855 - val_y2_output_root_mean_squared_error: 1.8822
# Epoch 485/500
# 614/614 [==============================] - 0s 148us/sample - loss: 0.3167 - y1_output_loss: 0.1079 - y2_output_loss: 0.2100 - y1_output_root_mean_squared_error: 0.3294 - y2_output_root_mean_squared_error: 0.4563 - val_loss: 1.4224 - val_y1_output_loss: 0.3692 - val_y2_output_loss: 1.1175 - val_y1_output_root_mean_squared_error: 0.5881 - val_y2_output_root_mean_squared_error: 1.0376
# Epoch 486/500
# 614/614 [==============================] - 0s 150us/sample - loss: 0.2857 - y1_output_loss: 0.1092 - y2_output_loss: 0.1744 - y1_output_root_mean_squared_error: 0.3320 - y2_output_root_mean_squared_error: 0.4189 - val_loss: 0.8774 - val_y1_output_loss: 0.1924 - val_y2_output_loss: 0.6943 - val_y1_output_root_mean_squared_error: 0.4407 - val_y2_output_root_mean_squared_error: 0.8265
# Epoch 487/500
# 614/614 [==============================] - 0s 146us/sample - loss: 0.3278 - y1_output_loss: 0.0981 - y2_output_loss: 0.2270 - y1_output_root_mean_squared_error: 0.3142 - y2_output_root_mean_squared_error: 0.4786 - val_loss: 0.8187 - val_y1_output_loss: 0.1765 - val_y2_output_loss: 0.6460 - val_y1_output_root_mean_squared_error: 0.4216 - val_y2_output_root_mean_squared_error: 0.8006
# Epoch 488/500
# 614/614 [==============================] - 0s 147us/sample - loss: 0.3394 - y1_output_loss: 0.1101 - y2_output_loss: 0.2268 - y1_output_root_mean_squared_error: 0.3324 - y2_output_root_mean_squared_error: 0.4784 - val_loss: 0.7468 - val_y1_output_loss: 0.1856 - val_y2_output_loss: 0.5798 - val_y1_output_root_mean_squared_error: 0.4330 - val_y2_output_root_mean_squared_error: 0.7479
# Epoch 489/500
# 614/614 [==============================] - 0s 149us/sample - loss: 0.2757 - y1_output_loss: 0.0976 - y2_output_loss: 0.1761 - y1_output_root_mean_squared_error: 0.3136 - y2_output_root_mean_squared_error: 0.4211 - val_loss: 0.8231 - val_y1_output_loss: 0.2234 - val_y2_output_loss: 0.6143 - val_y1_output_root_mean_squared_error: 0.4731 - val_y2_output_root_mean_squared_error: 0.7741
# Epoch 490/500
# 614/614 [==============================] - 0s 149us/sample - loss: 0.2627 - y1_output_loss: 0.1005 - y2_output_loss: 0.1634 - y1_output_root_mean_squared_error: 0.3159 - y2_output_root_mean_squared_error: 0.4037 - val_loss: 0.8012 - val_y1_output_loss: 0.2082 - val_y2_output_loss: 0.6041 - val_y1_output_root_mean_squared_error: 0.4575 - val_y2_output_root_mean_squared_error: 0.7693
# Epoch 491/500
# 614/614 [==============================] - 0s 147us/sample - loss: 0.3869 - y1_output_loss: 0.1510 - y2_output_loss: 0.2353 - y1_output_root_mean_squared_error: 0.3873 - y2_output_root_mean_squared_error: 0.4868 - val_loss: 0.8124 - val_y1_output_loss: 0.1890 - val_y2_output_loss: 0.6158 - val_y1_output_root_mean_squared_error: 0.4391 - val_y2_output_root_mean_squared_error: 0.7871
# Epoch 492/500
# 614/614 [==============================] - 0s 152us/sample - loss: 0.3142 - y1_output_loss: 0.1045 - y2_output_loss: 0.2078 - y1_output_root_mean_squared_error: 0.3235 - y2_output_root_mean_squared_error: 0.4577 - val_loss: 0.8681 - val_y1_output_loss: 0.2776 - val_y2_output_loss: 0.6076 - val_y1_output_root_mean_squared_error: 0.5178 - val_y2_output_root_mean_squared_error: 0.7746
# Epoch 493/500
# 614/614 [==============================] - 0s 150us/sample - loss: 0.4517 - y1_output_loss: 0.1367 - y2_output_loss: 0.3133 - y1_output_root_mean_squared_error: 0.3691 - y2_output_root_mean_squared_error: 0.5616 - val_loss: 1.1660 - val_y1_output_loss: 0.2611 - val_y2_output_loss: 0.9220 - val_y1_output_root_mean_squared_error: 0.5114 - val_y2_output_root_mean_squared_error: 0.9510
# Epoch 494/500
# 614/614 [==============================] - 0s 151us/sample - loss: 0.3043 - y1_output_loss: 0.1187 - y2_output_loss: 0.1846 - y1_output_root_mean_squared_error: 0.3451 - y2_output_root_mean_squared_error: 0.4303 - val_loss: 0.9913 - val_y1_output_loss: 0.3156 - val_y2_output_loss: 0.6938 - val_y1_output_root_mean_squared_error: 0.5539 - val_y2_output_root_mean_squared_error: 0.8273
# Epoch 495/500
# 614/614 [==============================] - 0s 150us/sample - loss: 0.6561 - y1_output_loss: 0.1976 - y2_output_loss: 0.4541 - y1_output_root_mean_squared_error: 0.4452 - y2_output_root_mean_squared_error: 0.6767 - val_loss: 0.7889 - val_y1_output_loss: 0.1968 - val_y2_output_loss: 0.5877 - val_y1_output_root_mean_squared_error: 0.4476 - val_y2_output_root_mean_squared_error: 0.7672
# Epoch 496/500
# 614/614 [==============================] - 0s 146us/sample - loss: 0.3360 - y1_output_loss: 0.1180 - y2_output_loss: 0.2233 - y1_output_root_mean_squared_error: 0.3422 - y2_output_root_mean_squared_error: 0.4678 - val_loss: 2.6017 - val_y1_output_loss: 0.3286 - val_y2_output_loss: 2.3206 - val_y1_output_root_mean_squared_error: 0.5705 - val_y2_output_root_mean_squared_error: 1.5087
# Epoch 497/500
# 614/614 [==============================] - 0s 145us/sample - loss: 0.3713 - y1_output_loss: 0.1301 - y2_output_loss: 0.2394 - y1_output_root_mean_squared_error: 0.3618 - y2_output_root_mean_squared_error: 0.4903 - val_loss: 1.0708 - val_y1_output_loss: 0.3746 - val_y2_output_loss: 0.7126 - val_y1_output_root_mean_squared_error: 0.6107 - val_y2_output_root_mean_squared_error: 0.8353
# Epoch 498/500
# 614/614 [==============================] - 0s 147us/sample - loss: 0.3623 - y1_output_loss: 0.1104 - y2_output_loss: 0.2535 - y1_output_root_mean_squared_error: 0.3332 - y2_output_root_mean_squared_error: 0.5013 - val_loss: 1.1815 - val_y1_output_loss: 0.2576 - val_y2_output_loss: 0.9497 - val_y1_output_root_mean_squared_error: 0.5005 - val_y2_output_root_mean_squared_error: 0.9649
# Epoch 499/500
# 614/614 [==============================] - 0s 162us/sample - loss: 0.2499 - y1_output_loss: 0.0988 - y2_output_loss: 0.1561 - y1_output_root_mean_squared_error: 0.3129 - y2_output_root_mean_squared_error: 0.3899 - val_loss: 1.1175 - val_y1_output_loss: 0.3566 - val_y2_output_loss: 0.7997 - val_y1_output_root_mean_squared_error: 0.5944 - val_y2_output_root_mean_squared_error: 0.8742
# Epoch 500/500
# 614/614 [==============================] - 0s 154us/sample - loss: 0.3771 - y1_output_loss: 0.1226 - y2_output_loss: 0.2599 - y1_output_root_mean_squared_error: 0.3505 - y2_output_root_mean_squared_error: 0.5042 - val_loss: 2.1925 - val_y1_output_loss: 0.4290 - val_y2_output_loss: 1.8251 - val_y1_output_root_mean_squared_error: 0.6457 - val_y2_output_root_mean_squared_error: 1.3325

# %% [markdown]
# ## Evaluate the Model and Plot Metrics

# %%
# Test the model and print loss and mse for both outputs
loss, Y1_loss, Y2_loss, Y1_rmse, Y2_rmse = model.evaluate(x=norm_test_X, y=test_Y)
print("Loss = {}, Y1_loss = {}, Y1_mse = {}, Y2_loss = {}, Y2_mse = {}".format(loss, Y1_loss, Y1_rmse, Y2_loss, Y2_rmse))
# Out:
# 154/154 [==============================] - 0s 44us/sample - loss: 2.1925 - y1_output_loss: 0.4214 - y2_output_loss: 1.7697 - y1_output_root_mean_squared_error: 0.6457 - y2_output_root_mean_squared_error: 1.3325
# Loss = 2.1924540191501767, Y1_loss = 0.4213651716709137, Y1_mse = 0.6456853151321411, Y2_loss = 1.7697101831436157, Y2_mse = 1.3324956893920898

# %%
# Plot the loss and mse
Y_pred = model.predict(norm_test_X)
plot_diff(test_Y[0], Y_pred[0], title='Y1')
plot_diff(test_Y[1], Y_pred[1], title='Y2')
plot_metrics(metric_name='y1_output_root_mean_squared_error', title='Y1 RMSE', ylim=6)
plot_metrics(metric_name='y2_output_root_mean_squared_error', title='Y2 RMSE', ylim=7)
